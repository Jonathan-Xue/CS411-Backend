# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint
import requests
from bs4 import BeautifulSoup

# %%
grades = pd.read_csv('cs-course-grades.csv', index_col=False)
old_primary_instructors = list(set(grades['primaryInstructor'].to_list()))

# %%
def display_name_normally(name):
    parts = name.split(", ")
    normal_order = parts[1:] + [parts[0]]
    return " ".join(normal_order)

def remove_middle_name(name):
    parts = [r for r in re.split(" |\.", name) if r and len(r) > 0]
    if len(parts) > 2:
        return " ".join([parts[0], parts[2]])
    else:
        return name

primary_instructors = [remove_middle_name(display_name_normally(n)) for n in old_primary_instructors]
# pprint(primary_instructors)

raw_to_refined_names = {}
for i in range(len(primary_instructors)):
    raw_to_refined_names[old_primary_instructors[i]] = primary_instructors[i]
    
raw_to_refined_names['Fagen, Wade A'] = 'Wade Fagen-Ulmschneider'
raw_to_refined_names['Fagen-Ulmschnei, Wade A'] = 'Wade Fagen-Ulmschneider'
raw_to_refined_names['Hasegawa-Johnso, Mark A'] = 'Mark Hasegawa-Johnson'
# pprint(raw_to_refined_names)

# %%
grades = grades.replace({"primaryInstructor": raw_to_refined_names })
grades.to_csv('cs-course-grades.csv', index=False)

# %%
grades = pd.read_csv('cs-course-grades.csv', index_col=False)
primary_instructors = list(set(grades['primaryInstructor'].to_list()))

# %%
research_urls = [
    'http://cs.illinois.edu/research/architecture-compilers-and-parallel-computing', 
    'http://cs.illinois.edu/research/artificial-intelligence',
    'http://cs.illinois.edu/research/bioinformatics-and-computational-biology',
    'http://cs.illinois.edu/research/computers-and-education',
    'http://cs.illinois.edu/research/data-and-information-systems',
    'http://cs.illinois.edu/research/interactive-computing',
    'http://cs.illinois.edu/research/programming-languages-formal-methods-and-software-engineering',
    'http://cs.illinois.edu/research/scientific-computing',
    'http://cs.illinois.edu/research/security-and-privacy',
    'http://cs.illinois.edu/research/systems-and-networking',
    'http://cs.illinois.edu/research/theory-and-algorithms',
]

prof_research_dict = {}
for url in research_urls:
    r = requests.get(url)
    page = BeautifulSoup(r.content, 'html.parser')
    table = page.find('table')
    table_entries = table.find_all('tr')
    for te in table_entries:
        try:
            prof_td, research_td = te.find_all('td')
            prof = remove_middle_name(prof_td.find('a').text)
            research = research_td.text
            
            if prof in prof_research_dict:
                prof_research_dict[prof] += research.split(", ")
            else:
                prof_research_dict[prof] = research.split(", ")
        except:
            pass
        
for prof in prof_research_dict:
    prof_research_dict[prof] = ", ".join(prof_research_dict[prof]).strip()

# %%
instructors = pd.DataFrame(primary_instructors, columns=['instructorName'])
instructors.index += 1 
instructors['researchInterests'] = instructors['instructorName'].map(prof_research_dict)
instructors.to_csv('cs-course-instructors.csv', index=True, index_label='instructorId')

# %%
instructors = pd.read_csv('cs-course-instructors.csv', index_col=False)

name_to_no_dict = dict(zip(instructors.instructorName, instructors.instructorId))
grades = grades.replace({"primaryInstructor": name_to_no_dict })
grades.to_csv('cs-course-grades.csv', index=False)

# %%
instructors.to_csv('cs-course-instructors.csv', index=False)
instructors[instructors['instructorName'].str.contains("David")]
# Out:
#      instructorId   instructorName  \
# 0               1  David Varodayan
# 55             56      David Nicol
# 67             68    David Forsyth
# 151           152      David Padua
#
#                                      researchInterests
# 0                                                  NaN
# 55   Modeling and Simulation, Security, Privacy, an...
# 67   Computer Vision, Object Recognition, Scene Und...
# 151  Compiler Techniques for Parallel Computing, Co...

# %%
# [grades['primaryInstructor'] == 4]
grades.to_csv('cs-course-grades.csv', index=False)
grades
# Out:
#      courseNo                      courseName  year    term  \
# 0         100            Freshman Orientation  2010    Fall
# 1         100            Freshman Orientation  2011    Fall
# 2         100            Freshman Orientation  2012    Fall
# 3         100            Freshman Orientation  2013    Fall
# 4         100            Freshman Orientation  2014    Fall
# 5         100            Freshman Orientation  2015    Fall
# 6         100            Freshman Orientation  2016    Fall
# 7         100            Freshman Orientation  2017    Fall
# 8         100            Freshman Orientation  2018    Fall
# 9         101    Intro Computing: Engrg & Sci  2010    Fall
# 10        101    Intro Computing: Engrg & Sci  2010  Spring
# 11        101    Intro Computing: Engrg & Sci  2010  Spring
# 12        101    Intro Computing: Engrg & Sci  2010  Spring
# 13        101    Intro Computing: Engrg & Sci  2010  Spring
# 14        101    Intro Computing: Engrg & Sci  2010  Spring
# 15        101    Intro Computing: Engrg & Sci  2010  Spring
# 16        101    Intro Computing: Engrg & Sci  2011    Fall
# 17        101    Intro Computing: Engrg & Sci  2011  Spring
# 18        101    Intro Computing: Engrg & Sci  2012    Fall
# 19        101    Intro Computing: Engrg & Sci  2013    Fall
# 20        101    Intro Computing: Engrg & Sci  2013  Spring
# 21        101    Intro Computing: Engrg & Sci  2014    Fall
# 22        101    Intro Computing: Engrg & Sci  2014  Spring
# 23        101    Intro Computing: Engrg & Sci  2015    Fall
# 24        101    Intro Computing: Engrg & Sci  2015  Spring
# 25        101    Intro Computing: Engrg & Sci  2016    Fall
# 26        101    Intro Computing: Engrg & Sci  2016  Spring
# 27        101    Intro Computing: Engrg & Sci  2017    Fall
# 28        101    Intro Computing: Engrg & Sci  2017  Spring
# 29        101    Intro Computing: Engrg & Sci  2018    Fall
# ..        ...                             ...   ...     ...
# 873       598      Autonomous Vehicles for AI  2017  Spring
# 874       598      Cutting-Edge Trends In DLR  2017  Spring
# 875       598              Data-Driven Design  2014    Fall
# 876       598              Data-Driven Design  2015    Fall
# 877       598                   Deep Learning  2018    Fall
# 878       598    Foundations of Data Curation  2018    Fall
# 879       598                Graphical Models  2016    Fall
# 880       598                      HCI for ML  2018    Fall
# 881       598  Improving Your Research Skills  2015  Spring
# 882       598  Lang/Abst f High-Perf Sci Comp  2018    Fall
# 883       598  Mach Lrng for Signal Processng  2012    Fall
# 884       598  Mach Lrng for Signal Processng  2013    Fall
# 885       598  Mach Lrng for Signal Processng  2014    Fall
# 886       598  Mach Lrng for Signal Processng  2017    Fall
# 887       598  Mach Lrng for Signal Processng  2018    Fall
# 888       598         Machine Learning Theory  2017    Fall
# 889       598  Machine Lrning Computation Bio  2015    Fall
# 890       598  Machine Lrning Computation Bio  2018    Fall
# 891       598            Parallel Programming  2014    Fall
# 892       598  Practical Statistical Learning  2018    Fall
# 893       598  Realiablity of Cloud-Scale Sys  2018    Fall
# 894       598         Secure Processor Design  2017    Fall
# 895       598                  Social Sensing  2017  Spring
# 896       598   Social Spaces on the Internet  2018    Fall
# 897       598                  Special Topics  2010  Spring
# 898       598                  Special Topics  2011    Fall
# 899       598                  Special Topics  2014  Spring
# 900       598         Stat Reinforcement lrng  2019  Spring
# 901       598       Statistical Reinforcement  2018    Fall
# 902       598             Topic in Algorithms  2015  Spring
#
#      primaryInstructor  aPlus    a  aMinus  bPlus    b  bMinus  cPlus   c  \
# 0                  151      0  154       0      0   30       0      0  22
# 1                  151      0  182       0      0   11       0      0  12
# 2                  151      0  188       0      0   21       0      0   6
# 3                  151      0  222       0      5   16       0      5   4
# 4                  151      0  232      11      3   11       3      2   6
# 5                  151      0  234       0      9   11       4      0  10
# 6                  151      0  279       0      5   11       0      1   6
# 7                  151      0  258       5     12   12       4      3   3
# 8                  162      0  290      10      9    4       2      1   2
# 9                   97     49   74      68     67   56      46     39  25
# 10                   7      9   13      11     18    6       9      2   6
# 11                  26      8   16      20     12    6       4      3   3
# 12                  15     15   11      23      9    6       6      1   1
# 13                  28     13   15      11      6    4       9      8   2
# 14                 131     13   12       9      6   11       7      0   5
# 15                  40      8   11       9     14    7       9      3   3
# 16                  97    115   80      49     47   41      45     26  20
# 17                  97    106  103      78     52   42      33     19  12
# 18                  97     86   61      56     40   52      41     36  30
# 19                  97     82   64      56     51   53      53     34  33
# 20                  97    104   85      71     67   44      45     38  24
# 21                  97     79   51      64     66   78      66     57  48
# 22                  97    113   74      59     56   42      37     33  29
# 23                  12      7  213      76     83  142      35     23  53
# 24                  97    116   83      83     68   73      66     48  43
# 25                 169     93  154     124     67   72      36     39  26
# 26                  12      6  341      78     65   96      14     13  33
# 27                 169    439   90      43     30   19      16      5   9
# 28                 169    239  159      72     61   44      24      9  12
# 29                 169    263  162      72     59   40      16     12  11
# ..                 ...    ...  ...     ...    ...  ...     ...    ...  ..
# 873                 68      0   26       0      0    0       0      0   1
# 874                 57     12   27      11      6    3       0      0   0
# 875                 67      2   10       2      6    1       1      0   0
# 876                 67      2    8       5      4    2       0      0   0
# 877                 42     12   17       7      1    2       0      0   0
# 878                 90     75   28       5      2    2       0      0   0
# 879                 27      3   19       1      0    0       0      0   0
# 880                 67      0   24      11      2    1       0      0   0
# 881                 63      9   12       4      3    0       0      0   0
# 882                106      0   19       1      1    0       0      0   0
# 883                160      7   20       4      1    0       0      0   0
# 884                160      4   47       3      5    1       0      0   0
# 885                160     12   23      16      0    2       5      1   0
# 886                160     17   32      19      2    0       1      0   1
# 887                160     14   43      11      0   13       2      0   0
# 888                  4      2   13       5      0    2       0      0   0
# 889                 82      5   13       2      1    0       0      0   0
# 890                 82      1   15       6      0    3       0      0   0
# 891                158      1   11       4      2    3       2      0   0
# 892                 21      1   90      13      7    3       0      0   2
# 893                109      3   13       9      5    1       0      0   0
# 894                 55      3   19       2      1    0       0      0   0
# 895                132      7   11       4      2    0       0      0   0
# 896                159     12   11       4      1    0       0      0   0
# 897                134      0   17       4      1    0       0      0   0
# 898                124      3    8       5      2    6       5      0   0
# 899                 77     14    3       1      0    2       1      0   0
# 900                164      8   10       3      1    1       0      0   0
# 901                164      4    8       5      1    0       0      1   2
# 902                 94      3    8       7      1    5       0      0   0
#
#      cMinus  dPlus   d  dMinus   f
# 0         0      0   9       0   9
# 1         0      0   5       0   7
# 2         0      0   1       0   9
# 3         0      2   1       0   9
# 4         1      0   2       1   9
# 5         0      0   2       2   4
# 6         0      0   3       0   6
# 7         2      0   0       1   4
# 8         2      0   1       0   1
# 9        16      9   6       8   2
# 10        1      3   0       0   0
# 11        0      1   1       0   3
# 12        4      1   0       0   2
# 13        2      2   2       1   1
# 14        4      3   2       0   3
# 15        2      2   0       0   2
# 16       14      8   7       6   4
# 17        9      4   4       8   4
# 18       14     10   4       4  15
# 19       28     23  13      11  17
# 20       22     14   5       4   8
# 21       39     35  20      13  50
# 22       21     18   8       8  23
# 23       12      0  26       0  24
# 24       16     20  19       7  35
# 25       11     10  15      14  21
# 26       11      0  15       0  16
# 27        6      1   9       0  14
# 28        9      7   2       4  15
# 29        5      8   7       6  11
# ..      ...    ...  ..     ...  ..
# 873       0      0   0       0   0
# 874       0      0   0       0   0
# 875       0      0   0       0   0
# 876       0      0   0       0   0
# 877       0      0   0       0   0
# 878       0      0   0       0   0
# 879       0      0   1       0   0
# 880       0      0   0       0   0
# 881       0      0   0       0   0
# 882       0      0   0       0   0
# 883       0      0   0       0   0
# 884       0      0   0       0   0
# 885       0      0   0       0   1
# 886       0      0   0       0   2
# 887       1      0   0       0   0
# 888       0      0   0       0   0
# 889       0      0   0       0   0
# 890       0      0   0       0   0
# 891       0      0   0       0   0
# 892       0      0   0       0   2
# 893       0      0   0       0   0
# 894       0      0   0       0   0
# 895       0      0   0       0   0
# 896       0      0   0       0   0
# 897       0      0   0       0   0
# 898       0      0   0       0   0
# 899       0      0   0       0   0
# 900       0      0   0       0   0
# 901       0      0   0       0   0
# 902       0      0   0       0   0
#
# [903 rows x 18 columns]
